# %%
#encoding=utf-8
import jieba.analyse
import jieba
# import Terry_toolkit as tkit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-57f3eeccfb0b> in <module>
#       2 import jieba.analyse
#       3 import jieba
# ----> 4 import Terry_toolkit as tkit
#
# ModuleNotFoundError: No module named 'Terry_toolkit'

# %%
# import jieba.analyse
"""jieba.analyse.extract_tags(sentence, topK=20, withWeight=False, allowPOS=())
sentence 为待提取的文本
topK 为返回几个 TF/IDF 权重最大的关键词，默认值为 20
withWeight 为是否一并返回关键词权重值，默认值为 False
allowPOS 仅包括指定词性的词，默认值为空，即不筛选
jieba.analyse.TFIDF(idf_path=None) 新建 TFIDF 实例，idf_path 为 IDF 频率文件"""

sentence="""
当下，“文旅+”的跨界融合已成为文
旅产业的发展趋势，文化旅游产业风头正劲，文旅融合、文旅融创，需要各业态联合发力，丰富文化旅游产品形态，延伸全域旅游产业链，进而满足人们日益增长的文化旅游需求，打造“全民文化旅游盛宴”。顺义，一个离美好近的地方。它牢牢扼守着北京的东北咽喉，是名副其实的“双门户”，一守“国家门户”，二守“郊区游门户”。它的美无处不在，从古到今，从初春到寒冬;从历史文化到本土现代文化，从自然风光到人文建设，它美得有活力、有气质、有灵气......十月的顺义，是一座七彩之城，浅山红(舞彩浅山红叶&红色旅游“焦庄户”)、葫芦橙(第二届葫芦文化艺术节)、采摘黄(秋季亲子采摘瓜果尝鲜)、葡萄紫(第三届欧菲堡文化艺术节)、艺术蓝(“十月金秋”文化活动)、自然绿(汉石桥湿地芦苇荡景观)、国潮青(中粮·祥云小镇户外艺术季)，让你遇见美好，遇见金秋。为进一步宣传顺义，推介顺义文化旅游企业，推动文化旅游与农业、体育等相关产业的深度融合，打造区域文化旅游品牌，顺义区文化和旅游局将联合各业态跨界举办“2019首届北京顺义金秋文化旅游活动季”。“2019北京顺义金秋文化旅游活动季”将以“七彩秋色、美好顺义”为主题，深挖全域特色秋季
旅游文化资源，融合红色文化特色旅游、传统民风民俗文化、体育、非物质文化遗产和优美生态环境等，进而提升顺义的知名度和影响力，提升社会效益和经济效益。“文旅+体育”，促进全民健身，注入文化活力文化是根植于内心的修养，旅游开阔人们的视野，体育则让人们拥有健康的体魄。文化、旅游、体育本为一体，既相互依存又各自独立。文旅与体育的融合，绝对不是简单的二者叠加，是需要不断地丰富、不断地创新以增强其持续吸引力，进而实现全民健身与文化旅游的相融。以“2019年全国重阳登高健身大会北京会场 北京市第十届登山大会暨顺义区“九九重阳”登山比赛” ，“2019年顺义第五届国际山地长跑舞彩浅山定向越野赛”为例，既具有文化积淀，又融入当地特色民俗文化，将拥有更多参与感、体验感和互动性强的“文旅赛事”注入文化活力，以期精彩地呈现在大众面前。两大“赛事”通过登山、定向越野、民俗文化汇演等活动形式，充分挖掘舞彩浅山传统登山文化内涵，融入龙湾屯镇红色旅游的特色文化以及民风民俗、生态环境等要素，在文旅体深度融合的背景下，实现了文化的“软滋润”和旅游的“硬吸引”，使相关体育活动更聚人气，更添魅力。舞彩浅山依托其优良的生态环境和
书画艺术展、国际酒庄文化交流、亲子嘉年华(艺术体验游园会)、音乐表演、艺术家主题创作展售”为主要内容，涵盖书画艺术、红酒文化、采摘、亲子艺术普及教育互动体验、非遗项目创作体验等项目，为“2019首届北京顺义金秋文化旅游活动季”增添新亮点，有利于整合各业态，促进地区全域旅游发展，打造顺义文化旅游品牌。为进一步探索文旅融合，助推全域旅游，加强“新亮点”的驱动，品味不同景区的独特魅力，汉石桥湿地景区、潮白河森林公园、顺义公园、奥林匹克水上公园、意大利农场、罗红摄影艺术馆、中粮·祥云小镇、顺义区影剧院、顺义福尼亚剧院等地都是不错的选择。随着全域旅游时代的到来，为进一步满足人们日益增长的多元化需求，顺义区文化和旅游局将持续挖掘区域特有的民俗文化内涵，依托现有文化旅游资源，做深、做足“文旅+”的概念，进一步打造区域旅游新业态、新亮点，促进顺义区全域旅游发展的迅速推进和强势崛起。   [SEP] [PT] 聚焦“文旅+”，助推全域旅游｜2019首届北京顺义金秋文化旅游活动季，多业态跨界共创“全民盛宴” [SEP] 


"""
keywords=jieba.analyse.extract_tags(sentence, topK=20, withWeight=False, allowPOS=())
print (" ".join(keywords))
# ————————————————
# 版权声明：本文为CSDN博主「Duyuankai1992」的原创文章，遵循 CC 4.0 BY-SA 版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/qq_37879432/article/details/78655886
# Out:
# 文化 旅游 顺义 葫芦 文旅 全域 2019 顺义区 金秋 体验 艺术节 艺术 舞彩 浅山 欧菲堡 北京 活动 文化遗产 龙湾 体育

# %%
import random,os

# os.chdir('D:\DOCUMENT/U1\Python3_Demo\TL_NER\DATA')

# f_tar = open('fenci_data_target.txt', 'r', encoding='utf-8')

# data_tar = f_tar.readlines()

#随机从txt文件中提取50行
# ran_tar = random.sample(data_tar, 50)

for src in sentence:
    src_temp = src.strip()
    print('src_temp',src_temp)
    print(jieba.analyse.extract_tags(sentence=src_temp,topK=10,allowPOS=('ns','n')))
# ————————————————
# 版权声明：本文为CSDN博主「不想熬夜的女程序媛」的原创文章，遵循 CC 4.0 BY-SA 版权协议，转载请附上原文出处链接及本声明。
# 原文链接：https://blog.csdn.net/qq_38101190/article/details/90750188
# Out:
# src_temp
# []
# src_temp 当
# []
# src_temp 下
# []
# src_temp ，
# []
# src_temp “
# []
# src_temp 文
# []
# src_temp 旅
# []
# src_temp +
# []
# src_temp ”
# []
# src_temp 的
# []
# src_temp 跨
# []
# src_temp 界
# []
# src_temp 融
# []
# src_temp 合
# []
# src_temp 已
# []
# src_temp 成
# []
# src_temp 为
# []
# src_temp 文
# []
# src_temp
# []
# src_temp 旅
# []
# src_temp 产
# []
# src_temp 业
# []
# src_temp 的
# []
# src_temp 发
# []
# src_temp 展
# []
# src_temp 趋
# []
# src_temp 势
# []
# src_temp ，
# []
# src_temp 文
# []
# src_temp 化
# []
# src_temp 旅
# []
# src_temp 游
# []
# src_temp 产
# []
# src_temp 业
# []
# src_temp 风
# []
# src_temp 头
# []
# src_temp 正
# []
# src_temp 劲
# []
# src_temp ，
# []
# src_temp 文
# []
# src_temp 旅
# []
# src_temp 融
# []
# src_temp 合
# []
# src_temp 、
# []
# src_temp 文
# []
# src_temp 旅
# []
# src_temp 融
# []
# src_temp 创
# []
# src_temp ，
# []
# src_temp 需
# []
# src_temp 要
# []
# src_temp 各
# []
# src_temp 业
# []
# src_temp 态
# []
# src_temp 联
# []
# src_temp 合
# ...
